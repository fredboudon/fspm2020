# %%
from pgljupyter import *

# %% [markdown]
# # Simple modelling of a broccoli

# %%
# %%lpy -w 6 -a True
# a = 40
# f = lambda s : s/2.
# Axiom: ,(2)_(0.3)FA(1)
# production:
# derivation length:5
# A(s) --> _(0.2*s)[^(a)F(s)A(f(s))][/(90)^(a)F(s)A(f(s))][/(180)^(a)F(s)A(f(s))][/(270)^(a)F(s)A(f(s))]/(137.5)F(s)A(f(s))
# interpretation:
# A(s) --> @O(2*s)
# Out:
# LsystemWidget(animate=True, derivationLength=6, is_magic=True, scene={'data': b'x\xdaSLrw\xf5\xf7e`Pp\xe0\xe5R…
